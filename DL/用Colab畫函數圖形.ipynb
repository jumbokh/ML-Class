# %% [markdown]
# <a href="https://colab.research.google.com/github/jumbokh/ML-Class/blob/main/DL/%E7%94%A8Colab%E7%95%AB%E5%87%BD%E6%95%B8%E5%9C%96%E5%BD%A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(-2,2,5)

# %%
x
# Out:
# array([-2., -1.,  0.,  1.,  2.])

# %%
y = x**2
y
# Out:
# array([4., 1., 0., 1., 4.])

# %%
plt.plot(x,y)

# %%
x = np.linspace(-2,2,100)
y = x**2

# %%
plt.plot(x,y)

# %%
plt.xkcd()

# %%
plt.plot(x,y)
