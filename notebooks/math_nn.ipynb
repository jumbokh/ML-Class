# %% [markdown]
# <a href="https://colab.research.google.com/github/jumbokh/ML-Class/blob/main/math_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# y=2x-1
'''
import numpy as np
import tensorflow as tf
import keras as keras
model=keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squard_error')

x=np.array([-1.0,0.0,1.0,2.0,3.0,4.0],dtype=float)
y=np.array([-3.0,-1.0,1.0,3.0,5.0,7.0],dtype=float)

model.fit(x,y,batch_size=10,epochs=500)

print(model.predict([10.0]))
'''

# %% [markdown]
# </pre>

# %%
import numpy as np
import tensorflow as tf
import keras as keras
from keras import losses

# %%
model=keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])
#model.compile(optimizer='sgd', loss='mean_squard_error')
model.compile(loss='mean_squared_error', optimizer='sgd')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
x=np.array([-1.0,0.0,1.0,2.0,3.0,4.0],dtype=float)
y=np.array([-3.0,-1.0,1.0,3.0,5.0,7.0],dtype=float)

# %%
model.fit(x,y,batch_size=10,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 393ms/step - loss: 3.5687
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.9694
# Epoch 3/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.4945
# Epoch 4/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.1177
# Epoch 5/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.8180
# Epoch 6/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.5791
# Epoch 7/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3881
# Epoch 8/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2349
# Epoch 9/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1113
# Epoch 10/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0113
# Epoch 11/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.9298
# Epoch 12/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8629
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.984934]]
