# %%
# y=2x-1
'''
import numpy as np
import tensorflow as tf
import keras as keras
model=keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squard_error')

x=np.array([-1.0,0.0,1.0,2.0,3.0,4.0],dtype=float)
y=np.array([-3.0,-1.0,1.0,3.0,5.0,7.0],dtype=float)

model.fit(x,y,batch_size=10,epochs=500)

print(model.predict([10.0]))
'''

# %%
# y=(x * 3) mod 100

# %% [markdown]
# </pre>

# %%
import numpy as np
import tensorflow as tf
import keras as keras
from keras import losses

# %%
n = list(range(100))
y=[]
for x in n:
  i = (x*3)%100
  y.append(i)
print(y)
# Out:
# [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97]

# %%
import pandas as pd
dic = {
    "num": pd.Series(range(100)),
    "anti": y
}

# %%
df = pd.DataFrame(dic)
df
# Out:
#     num  anti
# 0     0     0
# 1     1     3
# 2     2     6
# 3     3     9
# 4     4    12
# ..  ...   ...
# 95   95    85
# 96   96    88
# 97   97    91
# 98   98    94
# 99   99    97
#
# [100 rows x 2 columns]

# %%
df['anti'][67]
# Out:
# 1

# %%
model=keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])
#model.compile(optimizer='sgd', loss='mean_squard_error')
model.compile(loss='mean_squared_error', optimizer='sgd')

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(units=256, input_dim=1, kernel_initializer='normal', activation='relu'))
model.add(keras.layers.Dense(units=100, kernel_initializer='normal', activation='softmax'))
model.compile(loss='mean_squared_error',optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 256)               512
#
#  dense_4 (Dense)             (None, 100)               25700
#
# ...
# Total params: 26212 (102.39 KB)
# Trainable params: 26212 (102.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
x = list(df['num'])
y = list(df['anti'])

# %%
history = model.fit(x,y,batch_size=10,epochs=500)
# Out:
# Epoch 1/500
# 10/10 [==============================] - 1s 3ms/step - loss: 3282.5100 - accuracy: 0.0200
# Epoch 2/500
# 10/10 [==============================] - 0s 3ms/step - loss: 3282.5103 - accuracy: 0.0000e+00
# Epoch 3/500
# 10/10 [==============================] - 0s 3ms/step - loss: 3282.5103 - accuracy: 0.0300
# Epoch 4/500
# 10/10 [==============================] - 0s 3ms/step - loss: 3282.5103 - accuracy: 0.0000e+00
# Epoch 5/500
# 10/10 [==============================] - 0s 4ms/step - loss: 3282.5103 - accuracy: 0.0100
# Epoch 6/500
# 10/10 [==============================] - 0s 3ms/step - loss: 3282.5103 - accuracy: 0.0100
# Epoch 7/500
# 10/10 [==============================] - 0s 4ms/step - loss: 3282.5103 - accuracy: 0.0100
# Epoch 8/500
# 10/10 [==============================] - 0s 3ms/step - loss: 3282.5100 - accuracy: 0.0200
# Epoch 9/500
# 10/10 [==============================] - 0s 3ms/step - loss: 3282.5098 - accuracy: 0.0200
# Epoch 10/500
# ...

# %%
u = model.predict([10.0])
# Out:
# 1/1 [==============================] - 0s 43ms/step

# %%
np.argmax(model.predict([10.0]),axis=-1)
#print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 43ms/step
# array([94])
